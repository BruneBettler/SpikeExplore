# %% [markdown]
# With flexible tentacle electrodes, because indidivudal electrode wires and their contact sites are independent in space, and because bundling is necessary prior to insertion in the brain, exact probe geometry is unknown.
#
# We can treat geometry as an uncertain latent variable.
#
# How sensitive are the following to perturbations of geometry G?
# - preprocessing
# - sorting
# - template shape
# - unit identity
# - quality metrics
#
#
# we can apply gaussian jitter per contact, smooth bending deformation, local tip displacement, and channel permutation errors.
